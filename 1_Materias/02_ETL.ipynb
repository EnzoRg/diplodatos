# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2024**
#
# ---
#
# ### **Análisis Exploratorio y Curación de Datos**
# ### Parte 1: Extracción, Transformación y Carga (ETL)
#
# ---

# %% [markdown]
# # Trabajo Práctico Entregable - Parte 1
#
# En esta notebook, vamos a cargar el conjunto de datos de [la compentencia Kaggle](https://www.kaggle.com/dansbecker/melbourne-housing-snapshot) sobre estimación de precios de ventas de propiedades en Melbourne, Australia.
#
# Utilizaremos el conjunto de datos reducido producido por [DanB](https://www.kaggle.com/dansbecker). Hemos subido una copia a un servidor de la Universidad Nacional de Córdoba para facilitar su acceso remoto.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sqlalchemy import create_engine, text
from dython.nominal import associations

# %%
sns.set_context('talk')
pd.options.display.float_format = '{:.2f}'.format

# %%
df_melb = pd.read_csv('../Data/melb_data.csv')

# %% [markdown]
# ## Exploracion de los datos

# %% [markdown]
# Utilizamos algunas funciones de Pandas que resultaran utiles para conocer el _Dataset_

# %%
df_melb.columns, df_melb.shape
# Out:
# (Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#         'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#         'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#         'Longtitude', 'Regionname', 'Propertycount'],
#        dtype='object'),
#  (13580, 21))

# %%
df_melb[['Suburb', 'Postcode', 'CouncilArea', 'Regionname']].sample(5)
# Out:
#              Suburb  Postcode  CouncilArea             Regionname
# 8350         Seddon   3011.00  Maribyrnong   Western Metropolitan
# 6293      Thornbury   3071.00      Darebin  Northern Metropolitan
# 5050      Reservoir   3073.00      Darebin  Northern Metropolitan
# 6419       Viewbank   3084.00      Banyule   Eastern Metropolitan
# 9346  Taylors Lakes   3038.00     Brimbank   Western Metropolitan

# %% [markdown]
# ## Ejercicio 1 - SQL:
#
# 1. Crear una base de datos en SQLite utilizando la libreria [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy).
# https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite
#
# 2. Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el _Dataset_ generado en clase con datos de airbnb y sus precios por codigo postal en otra.
#
# 3. Implementar consultas en SQL que respondan con la siguiente información:
#
#     - cantidad de registros totales por ciudad.
#     - cantidad de registros totales por barrio y ciudad.
#
# 4. Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL  para obtener un resultado similar a lo realizado con Pandas en clase.

# %% [markdown]
# Primero se importa dos elementos de la bilioteca [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy) para crear un motor de base de datos

# %%
from sqlalchemy import create_engine, text

# %% [markdown]
# Luego se crea un motor de base de datos que representa la conexión a una base de datos y se utiliza para enviar comandos SQL y recibir resultados

# %%
engine = create_engine('sqlite:///db_practico.sqlite3', echo=True)

# %% [markdown]
# Se escriben los datos del DataFrame ```df_melb``` en una tabla de datos llamada ``` db_melb ``` utilizando SQLAlchemy como motor de base de datos

# %%
df_melb.to_sql('db_melb', con=engine, if_exists="replace")
# Out:
# 2024-08-30 15:56:05,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 15:56:05,433 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("db_melb")
# 2024-08-30 15:56:05,434 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,436 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("db_melb")
# 2024-08-30 15:56:05,436 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,438 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-08-30 15:56:05,439 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,440 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='view' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-08-30 15:56:05,441 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,442 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("db_melb")
# 2024-08-30 15:56:05,443 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,444 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:05,445 INFO sqlalchemy.engine.Engine [raw sql] ('db_melb',)
# 2024-08-30 15:56:05,447 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("db_melb")
# 2024-08-30 15:56:05,447 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,448 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("db_melb")
# 2024-08-30 15:56:05,449 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,449 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:05,450 INFO sqlalchemy.engine.Engine [raw sql] ('db_melb',)
# 2024-08-30 15:56:05,452 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("db_melb")
# 2024-08-30 15:56:05,453 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,454 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_db_melb_index")
# 2024-08-30 15:56:05,455 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,456 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("db_melb")
# 2024-08-30 15:56:05,456 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,457 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_db_melb_index")
# 2024-08-30 15:56:05,458 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:05,459 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:05,459 INFO sqlalchemy.engine.Engine [raw sql] ('db_melb',)
# 2024-08-30 15:56:05,463 INFO sqlalchemy.engine.Engine
# DROP TABLE db_melb
# 2024-08-30 15:56:05,463 INFO sqlalchemy.engine.Engine [no key 0.00066s] ()
# 2024-08-30 15:56:05,474 INFO sqlalchemy.engine.Engine
# CREATE TABLE db_melb (
# 	"index" BIGINT,
# 	"Suburb" TEXT,
# 	"Address" TEXT,
# 	"Rooms" BIGINT,
# 	"Type" TEXT,
# 	"Price" FLOAT,
# 	"Method" TEXT,
# 	"SellerG" TEXT,
# 	"Date" TEXT,
# 	"Distance" FLOAT,
# 	"Postcode" FLOAT,
# 	"Bedroom2" FLOAT,
# 	"Bathroom" FLOAT,
# 	"Car" FLOAT,
# 	"Landsize" FLOAT,
# 	"BuildingArea" FLOAT,
# 	"YearBuilt" FLOAT,
# 	"CouncilArea" TEXT,
# 	"Lattitude" FLOAT,
# 	"Longtitude" FLOAT,
# 	"Regionname" TEXT,
# 	"Propertycount" FLOAT
# )
#
#
# 2024-08-30 15:56:05,474 INFO sqlalchemy.engine.Engine [no key 0.00059s] ()
# 2024-08-30 15:56:05,480 INFO sqlalchemy.engine.Engine CREATE INDEX ix_db_melb_index ON db_melb ("index")
# 2024-08-30 15:56:05,481 INFO sqlalchemy.engine.Engine [no key 0.00049s] ()
# 2024-08-30 15:56:05,716 INFO sqlalchemy.engine.Engine INSERT INTO db_melb ("index", "Suburb", "Address", "Rooms", "Type", "Price", "Method", "SellerG", "Date", "Distance", "Postcode", "Bedroom2", "Bathroom", "Car", "Landsize", "BuildingArea", "YearBuilt", "CouncilArea", "Lattitude", "Longtitude", "Regionname", "Propertycount") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2024-08-30 15:56:05,716 INFO sqlalchemy.engine.Engine [generated in 0.18459s] [(0, 'Abbotsford', '85 Turner St', 2, 'h', 1480000.0, 'S', 'Biggin', '3/12/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Yarra', -37.7996, 144.9984, 'Northern Metropolitan', 4019.0), (1, 'Abbotsford', '25 Bloomburg St', 2, 'h', 1035000.0, 'S', 'Biggin', '4/02/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 156.0, 79.0, 1900.0, 'Yarra', -37.8079, 144.9934, 'Northern Metropolitan', 4019.0), (2, 'Abbotsford', '5 Charles St', 3, 'h', 1465000.0, 'SP', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 0.0, 134.0, 150.0, 1900.0, 'Yarra', -37.8093, 144.9944, 'Northern Metropolitan', 4019.0), (3, 'Abbotsford', '40 Federation La', 3, 'h', 850000.0, 'PI', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 1.0, 94.0, None, None, 'Yarra', -37.7969, 144.9969, 'Northern Metropolitan', 4019.0), (4, 'Abbotsford', '55a Park St', 4, 'h', 1600000.0, 'VB', 'Nelson', '4/06/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 120.0, 142.0, 2014.0, 'Yarra', -37.8072, 144.9941, 'Northern Metropolitan', 4019.0), (5, 'Abbotsford', '129 Charles St', 2, 'h', 941000.0, 'S', 'Jellis', '7/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 181.0, None, None, 'Yarra', -37.8041, 144.9953, 'Northern Metropolitan', 4019.0), (6, 'Abbotsford', '124 Yarra St', 3, 'h', 1876000.0, 'S', 'Nelson', '7/05/2016', 2.5, 3067.0, 4.0, 2.0, 0.0, 245.0, 210.0, 1910.0, 'Yarra', -37.8024, 144.9993, 'Northern Metropolitan', 4019.0), (7, 'Abbotsford', '98 Charles St', 2, 'h', 1636000.0, 'S', 'Nelson', '8/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 256.0, 107.0, 1890.0, 'Yarra', -37.806, 144.9954, 'Northern Metropolitan', 4019.0)  ... displaying 10 of 13580 total bound parameter sets ...  (13578, 'Williamstown', '96 Verdon St', 4, 'h', 2500000.0, 'PI', 'Sweeney', '26/08/2017', 6.8, 3016.0, 4.0, 1.0, 5.0, 866.0, 157.0, 1920.0, None, -37.85908, 144.89299, 'Western Metropolitan', 6380.0), (13579, 'Yarraville', '6 Agnes St', 4, 'h', 1285000.0, 'SP', 'Village', '26/08/2017', 6.3, 3013.0, 4.0, 1.0, 1.0, 362.0, 112.0, 1920.0, None, -37.81188, 144.88449, 'Western Metropolitan', 6543.0)]
# 2024-08-30 15:56:05,817 INFO sqlalchemy.engine.Engine COMMIT
# 13580

# %% [markdown]
# ### 1.2 Ingesta de datos

# %% [markdown]
# Para crear el DataFrame ```df_airbnb``` se debe primero descargar el .csv. Este pesa > 90 mb. Para poder acceder de forma más rapida exiten varias [maneras](https://stackoverflow.com/questions/71619540/how-to-upload-a-62-gb-datasets-to-google-colab)

# %% [markdown]
# Tambien se determinan las columnas de interes, ya que muchas eran _reviews_ de los mismos huespedes y generaban largas cadenas de texto que para este trabajo no lo vas a utilizar

# %%
interesting_cols = [
  'street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
  'price', 'weekly_price', 'monthly_price',
  'latitude', 'longitude',]

# %% [markdown]
# Se carga el DataFrame con las columnas de interes y se crea la base de datos ```db_airbnb```

# %%
df_airbnb = pd.read_csv('../Data/cleansed_listings_dec18.csv', usecols=interesting_cols)
# Out:
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\3950007558.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_airbnb = pd.read_csv('../Data/cleansed_listings_dec18.csv', usecols=interesting_cols)

# %%
df_airbnb.columns, df_airbnb.shape
# Out:
# (Index(['street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
#         'latitude', 'longitude', 'price', 'weekly_price', 'monthly_price'],
#        dtype='object'),
#  (22895, 11))

# %%
df_airbnb.to_sql('db_airbnb', con=engine, if_exists="replace")
# Out:
# 2024-08-30 15:56:06,318 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 15:56:06,322 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("db_airbnb")
# 2024-08-30 15:56:06,323 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,325 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("db_airbnb")
# 2024-08-30 15:56:06,325 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,326 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-08-30 15:56:06,327 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,328 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='view' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2024-08-30 15:56:06,329 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,330 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("db_airbnb")
# 2024-08-30 15:56:06,331 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,332 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:06,333 INFO sqlalchemy.engine.Engine [raw sql] ('db_airbnb',)
# 2024-08-30 15:56:06,334 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("db_airbnb")
# 2024-08-30 15:56:06,334 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,335 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("db_airbnb")
# 2024-08-30 15:56:06,337 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,339 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:06,341 INFO sqlalchemy.engine.Engine [raw sql] ('db_airbnb',)
# 2024-08-30 15:56:06,344 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("db_airbnb")
# 2024-08-30 15:56:06,345 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,347 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_db_airbnb_index")
# 2024-08-30 15:56:06,347 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,349 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("db_airbnb")
# 2024-08-30 15:56:06,350 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,351 INFO sqlalchemy.engine.Engine PRAGMA main.index_info("ix_db_airbnb_index")
# 2024-08-30 15:56:06,352 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,353 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2024-08-30 15:56:06,354 INFO sqlalchemy.engine.Engine [raw sql] ('db_airbnb',)
# 2024-08-30 15:56:06,358 INFO sqlalchemy.engine.Engine
# DROP TABLE db_airbnb
# 2024-08-30 15:56:06,359 INFO sqlalchemy.engine.Engine [no key 0.00119s] ()
# 2024-08-30 15:56:06,374 INFO sqlalchemy.engine.Engine
# CREATE TABLE db_airbnb (
# 	"index" BIGINT,
# 	street TEXT,
# 	neighborhood TEXT,
# 	city TEXT,
# 	suburb TEXT,
# 	state TEXT,
# 	zipcode TEXT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	price BIGINT,
# 	weekly_price FLOAT,
# 	monthly_price FLOAT
# )
#
#
# 2024-08-30 15:56:06,375 INFO sqlalchemy.engine.Engine [no key 0.00090s] ()
# 2024-08-30 15:56:06,383 INFO sqlalchemy.engine.Engine CREATE INDEX ix_db_airbnb_index ON db_airbnb ("index")
# 2024-08-30 15:56:06,385 INFO sqlalchemy.engine.Engine [no key 0.00109s] ()
# 2024-08-30 15:56:06,669 INFO sqlalchemy.engine.Engine INSERT INTO db_airbnb ("index", street, neighborhood, city, suburb, state, zipcode, latitude, longitude, price, weekly_price, monthly_price) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2024-08-30 15:56:06,669 INFO sqlalchemy.engine.Engine [generated in 0.23442s] [(0, 'Bulleen, VIC, Australia', 'Balwyn North', 'Manningham', 'Bulleen', 'VIC', '3105', -37.77268393, 145.0921328, 60, None, None), (1, 'Brunswick East, VIC, Australia', 'Brunswick', 'Moreland', 'Brunswick East', 'VIC', '3057', -37.76650512, 144.9807361, 35, 200.0, 803.0), (2, 'St Kilda, VIC, Australia', 'St Kilda', 'Port Phillip', 'St Kilda', 'VIC', '3182', -37.85975502, 144.9773691, 159, 1253.0, 4452.0), (3, 'Thornbury, VIC, Australia', 'Thornbury', 'Darebin', 'Thornbury', 'VIC', '3071', -37.75897072, 144.9892279, 50, 250.0, 920.0), (4, 'St Kilda East, VIC, Australia', 'St Kilda East', 'Port Phillip', 'St Kilda East', 'VIC', '3183', -37.8645303, 144.9922379, 69, 400.0, 1900.0), (5, 'Berwick, VIC, Australia', None, 'Casey', 'Berwick', 'VIC', '3806', -38.05725414, 145.3393561, 98, 540.0, None), (6, 'Reservoir, VIC, Australia', None, 'Darebin', 'Reservoir', 'VIC', '3073', -37.69729418, 145.0008156, 50, 335.0, 1400.0), (7, 'East Melbourne, VIC, Australia', None, 'Melbourne', 'East Melbourne', 'VIC', '3002', -37.81026723, 144.98592, 100, None, None)  ... displaying 10 of 22895 total bound parameter sets ...  (22893, 'Southbank, VIC, Australia', 'Southbank', 'Melbourne', 'Southbank', 'VIC', 3006.0, -37.8277951, 144.9549869, 130, None, None), (22894, 'Carlton, VIC, Australia', 'Carlton', 'Melbourne', 'Carlton', 'VIC', 3053.0, -37.80518635, 144.9623991, 179, None, None)]
# 2024-08-30 15:56:06,814 INFO sqlalchemy.engine.Engine COMMIT
# 22895

# %% [markdown]
# ### 1.3 Consultas SQL

# %% [markdown]
# Mediante la funciuon ```read_sql_query``` de Pandas se pueden ejecutar consultas de manera más facil, pasando solo la consulta como una cadena de texto y el motor previamente creado

# %% [markdown]
# #### Cantidad de registros totales por ciudad

# %%
query = "SELECT city, COUNT(*) AS total_city FROM db_airbnb GROUP BY city;"
pd.read_sql_query(query, engine)
# Out:
# 2024-08-30 15:56:06,830 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 15:56:06,831 INFO sqlalchemy.engine.Engine SELECT city, COUNT(*) AS total_city FROM db_airbnb GROUP BY city;
# 2024-08-30 15:56:06,832 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,846 INFO sqlalchemy.engine.Engine ROLLBACK
#                  city  total_city
# 0             Banyule         203
# 1             Bayside         375
# 2          Boroondara         664
# 3            Brimbank         108
# 4            Cardinia         123
# 5               Casey         153
# 6             Darebin         698
# 7           Frankston         177
# 8           Glen Eira         631
# 9   Greater Dandenong         147
# 10        Hobsons Bay         239
# 11               Hume         170
# 12           Kingston         309
# 13               Knox         175
# 14         Manningham         313
# 15        Maribyrnong         436
# 16          Maroondah         115
# 17          Melbourne        7368
# 18             Melton          95
# 19             Monash         571
# 20      Moonee Valley         344
# 21           Moreland         967
# 22          Nillumbik          88
# 23       Port Phillip        2808
# 24        Stonnington        1621
# 25         Whitehorse         614
# 26         Whittlesea         137
# 27            Wyndham         426
# 28              Yarra        2049
# 29       Yarra Ranges         771

# %% [markdown]
# #### Cantidad de registros totales por barrio y ciudad

# %%
query = 'SELECT neighborhood, city, COUNT(*) AS total_neighborhood_and_city FROM db_airbnb GROUP BY neighborhood, city ORDER BY COUNT(*) DESC;'
pd.read_sql_query(query, engine)
# Out:
# 2024-08-30 15:56:06,859 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 15:56:06,860 INFO sqlalchemy.engine.Engine SELECT neighborhood, city, COUNT(*) AS total_neighborhood_and_city FROM db_airbnb GROUP BY neighborhood, city ORDER BY COUNT(*) DESC;
# 2024-08-30 15:56:06,860 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:06,888 INFO sqlalchemy.engine.Engine ROLLBACK
#                   neighborhood           city  total_neighborhood_and_city
# 0    Central Business District      Melbourne                         3726
# 1                    Southbank      Melbourne                         1204
# 2                     St Kilda   Port Phillip                         1082
# 3                         None   Yarra Ranges                          771
# 4                  South Yarra    Stonnington                          759
# ..                         ...            ...                          ...
# 129                  Bentleigh        Bayside                            1
# 130                     Elwood        Bayside                            1
# 131                  Glen Iris     Whitehorse                            1
# 132                 Kensington  Moonee Valley                            1
# 133            South Melbourne      Melbourne                            1
#
# [134 rows x 3 columns]

# %% [markdown]
# ### 1.4 Combinacion de los _Dataset_

# %% [markdown]
# Para combinar las dos tablas se utiliza la operacion ```LEFT JOIN```, la cual permite combinarlas pero garantiza que todos los registros de la tabla izquierda ```db_melb``` esten presentes en el resultado final, incluso si no hay coincidencias en la tabla derecha ```db_airbnb```

# %%
query_join = "SELECT * FROM db_melb LEFT JOIN (SELECT CAST(zipcode AS int) as zipcode_int, AVG(db_airbnb.price) AS airbnb_price_mean, COUNT(zipcode) AS airbnb_record_count, AVG(weekly_price) AS airbnb_weekly_price_mean, AVG(monthly_price) AS airbnb_monthly_price_mean FROM db_airbnb GROUP BY zipcode_int) AS airbnb_price_by_zipcode ON airbnb_price_by_zipcode.zipcode_int = CAST(db_melb.Postcode AS INT)"

# %%
resultado = pd.read_sql_query(query_join, engine)
resultado[:20]
# Out:
# 2024-08-30 15:56:06,911 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-08-30 15:56:06,912 INFO sqlalchemy.engine.Engine SELECT * FROM db_melb LEFT JOIN (SELECT CAST(zipcode AS int) as zipcode_int, AVG(db_airbnb.price) AS airbnb_price_mean, COUNT(zipcode) AS airbnb_record_count, AVG(weekly_price) AS airbnb_weekly_price_mean, AVG(monthly_price) AS airbnb_monthly_price_mean FROM db_airbnb GROUP BY zipcode_int) AS airbnb_price_by_zipcode ON airbnb_price_by_zipcode.zipcode_int = CAST(db_melb.Postcode AS INT)
# 2024-08-30 15:56:06,913 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-08-30 15:56:07,067 INFO sqlalchemy.engine.Engine ROLLBACK
#     index      Suburb              Address  Rooms Type      Price Method  \
# 0       0  Abbotsford         85 Turner St      2    h 1480000.00      S
# 1       1  Abbotsford      25 Bloomburg St      2    h 1035000.00      S
# 2       2  Abbotsford         5 Charles St      3    h 1465000.00     SP
# 3       3  Abbotsford     40 Federation La      3    h  850000.00     PI
# 4       4  Abbotsford          55a Park St      4    h 1600000.00     VB
# 5       5  Abbotsford       129 Charles St      2    h  941000.00      S
# 6       6  Abbotsford         124 Yarra St      3    h 1876000.00      S
# 7       7  Abbotsford        98 Charles St      2    h 1636000.00      S
# 8       8  Abbotsford   6/241 Nicholson St      1    u  300000.00      S
# 9       9  Abbotsford        10 Valiant St      2    h 1097000.00      S
# 10     10  Abbotsford   411/8 Grosvenor St      2    u  700000.00     VB
# 11     11  Abbotsford      40 Nicholson St      3    h 1350000.00     VB
# 12     12  Abbotsford  123/56 Nicholson St      2    u  750000.00      S
# 13     13  Abbotsford        45 William St      2    h 1172500.00      S
# 14     14  Abbotsford   7/20 Abbotsford St      1    u  441000.00     SP
# 15     15  Abbotsford        16 William St      2    h 1310000.00      S
# 16     16  Abbotsford          42 Henry St      3    h 1200000.00      S
# 17     17  Abbotsford          78 Yarra St      3    h 1176500.00      S
# 18     18  Abbotsford     196 Nicholson St      3    h  955000.00      S
# 19     19  Abbotsford        42 Valiant St      2    h  890000.00      S
#
#     SellerG        Date  Distance  ...  CouncilArea  Lattitude  Longtitude  \
# 0    Biggin   3/12/2016      2.50  ...        Yarra     -37.80      145.00
# 1    Biggin   4/02/2016      2.50  ...        Yarra     -37.81      144.99
# 2    Biggin   4/03/2017      2.50  ...        Yarra     -37.81      144.99
# 3    Biggin   4/03/2017      2.50  ...        Yarra     -37.80      145.00
# 4    Nelson   4/06/2016      2.50  ...        Yarra     -37.81      144.99
# 5    Jellis   7/05/2016      2.50  ...        Yarra     -37.80      145.00
# 6    Nelson   7/05/2016      2.50  ...        Yarra     -37.80      145.00
# 7    Nelson   8/10/2016      2.50  ...        Yarra     -37.81      145.00
# 8    Biggin   8/10/2016      2.50  ...        Yarra     -37.80      145.00
# 9    Biggin   8/10/2016      2.50  ...        Yarra     -37.80      145.00
# 10   Jellis  12/11/2016      2.50  ...        Yarra     -37.81      145.01
# 11   Nelson  12/11/2016      2.50  ...        Yarra     -37.81      145.00
# 12   Biggin  12/11/2016      2.50  ...        Yarra     -37.81      145.00
# 13   Biggin  13/08/2016      2.50  ...        Yarra     -37.81      145.00
# 14     Greg  14/05/2016      2.50  ...        Yarra     -37.80      145.00
# 15   Jellis  15/10/2016      2.50  ...        Yarra     -37.81      145.00
# 16   Jellis  16/07/2016      2.50  ...        Yarra     -37.81      144.99
# 17   LITTLE  16/07/2016      2.50  ...        Yarra     -37.80      145.00
# 18  Collins  17/09/2016      2.50  ...        Yarra     -37.80      145.00
# 19   Biggin  17/09/2016      2.50  ...        Yarra     -37.80      145.00
#
#                Regionname  Propertycount  zipcode_int  airbnb_price_mean  \
# 0   Northern Metropolitan        4019.00      3067.00             130.62
# 1   Northern Metropolitan        4019.00      3067.00             130.62
# 2   Northern Metropolitan        4019.00      3067.00             130.62
# 3   Northern Metropolitan        4019.00      3067.00             130.62
# 4   Northern Metropolitan        4019.00      3067.00             130.62
# 5   Northern Metropolitan        4019.00      3067.00             130.62
# 6   Northern Metropolitan        4019.00      3067.00             130.62
# 7   Northern Metropolitan        4019.00      3067.00             130.62
# 8   Northern Metropolitan        4019.00      3067.00             130.62
# 9   Northern Metropolitan        4019.00      3067.00             130.62
# 10  Northern Metropolitan        4019.00      3067.00             130.62
# 11  Northern Metropolitan        4019.00      3067.00             130.62
# 12  Northern Metropolitan        4019.00      3067.00             130.62
# 13  Northern Metropolitan        4019.00      3067.00             130.62
# 14  Northern Metropolitan        4019.00      3067.00             130.62
# 15  Northern Metropolitan        4019.00      3067.00             130.62
# 16  Northern Metropolitan        4019.00      3067.00             130.62
# 17  Northern Metropolitan        4019.00      3067.00             130.62
# 18  Northern Metropolitan        4019.00      3067.00             130.62
# 19  Northern Metropolitan        4019.00      3067.00             130.62
#
#    airbnb_record_count  airbnb_weekly_price_mean  airbnb_monthly_price_mean
# 0               258.00                    605.15                    2187.03
# 1               258.00                    605.15                    2187.03
# 2               258.00                    605.15                    2187.03
# 3               258.00                    605.15                    2187.03
# 4               258.00                    605.15                    2187.03
# 5               258.00                    605.15                    2187.03
# 6               258.00                    605.15                    2187.03
# 7               258.00                    605.15                    2187.03
# 8               258.00                    605.15                    2187.03
# 9               258.00                    605.15                    2187.03
# 10              258.00                    605.15                    2187.03
# 11              258.00                    605.15                    2187.03
# 12              258.00                    605.15                    2187.03
# 13              258.00                    605.15                    2187.03
# 14              258.00                    605.15                    2187.03
# 15              258.00                    605.15                    2187.03
# 16              258.00                    605.15                    2187.03
# 17              258.00                    605.15                    2187.03
# 18              258.00                    605.15                    2187.03
# 19              258.00                    605.15                    2187.03
#
# [20 rows x 27 columns]

# %% [markdown]
# ## Ejercicio 2 - Pandas:
#
# 1. Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#  - Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.
#
#
# 2. Agregar información adicional respectiva al entorno de una propiedad a partir del [conjunto de datos de AirBnB](https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv) utilizado en el práctico.
#   1. Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna `price`, o aplicar múltiples transformaciones como la mediana o el mínimo.
#   1. Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.
#   2. Investigar al menos otras 2 variables que puedan servir para combinar los datos, y justificar si serían adecuadas o no. Pueden asumir que cuentan con la ayuda de anotadores expertos para encontrar equivalencias entre barrios o direcciones, o que cuentan con algoritmos para encontrar las n ubicaciones más cercanas a una propiedad a partir de sus coordenadas geográficas. **NO** es necesario que realicen la implementación.
#
# Pueden leer otras columnas del conjunto de AirBnB además de las que están en `interesting_cols`, si les parecen relevantes.

# %% [markdown]
# ### 2.1 Columnas de interes

# %% [markdown]
# Primero se ven los datos relevantes de todas las columnas

# %%
df_melb.describe(), df_melb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB
# (         Rooms      Price  Distance  Postcode  Bedroom2  Bathroom      Car  \
#  count 13580.00   13580.00  13580.00  13580.00  13580.00  13580.00 13518.00
#  mean      2.94 1075684.08     10.14   3105.30      2.91      1.53     1.61
#  std       0.96  639310.72      5.87     90.68      0.97      0.69     0.96
#  min       1.00   85000.00      0.00   3000.00      0.00      0.00     0.00
#  25%       2.00  650000.00      6.10   3044.00      2.00      1.00     1.00
#  50%       3.00  903000.00      9.20   3084.00      3.00      1.00     2.00
#  75%       3.00 1330000.00     13.00   3148.00      3.00      2.00     2.00
#  max      10.00 9000000.00     48.10   3977.00     20.00      8.00    10.00
#
#         Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
#  count  13580.00       7130.00    8205.00   13580.00    13580.00       13580.00
#  mean     558.42        151.97    1964.68     -37.81      145.00        7454.42
#  std     3990.67        541.01      37.27       0.08        0.10        4378.58
#  min        0.00          0.00    1196.00     -38.18      144.43         249.00
#  25%      177.00         93.00    1940.00     -37.86      144.93        4380.00
#  50%      440.00        126.00    1970.00     -37.80      145.00        6555.00
#  75%      651.00        174.00    1999.00     -37.76      145.06       10331.00
#  max   433014.00      44515.00    2018.00     -37.41      145.53       21650.00  ,
#  None)

# %% [markdown]
# Teniendo en cuenta la columna **Type:**
# - br - bedroom(s);
# - h - house,cottage,villa, semi,terrace;
# - u - unit, duplex;
# - t - townhouse;
# - dev site - development site;
# - o res - other residential.

# %% [markdown]
# Se clasifican las variables en **categóricas** y **numérica**

# %%
categorical = [var for var in df_melb.columns if df_melb[var].dtype=='O']
categorical
# Out:
# ['Suburb',
#  'Address',
#  'Type',
#  'Method',
#  'SellerG',
#  'Date',
#  'CouncilArea',
#  'Regionname']

# %%
df_melb.describe(include='O')
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname
# count        12211                  13580
# unique          33                      8
# top       Moreland  Southern Metropolitan
# freq          1163                   4695

# %%
numerical = [var for var in df_melb.columns if (df_melb[var].dtype == float) or (df_melb[var].dtype == int)]
numerical
# Out:
# ['Price',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'Lattitude',
#  'Longtitude',
#  'Propertycount']

# %%
round(df_melb.describe(),2)
# Out:
#          Rooms      Price  Distance  Postcode  Bedroom2  Bathroom      Car  \
# count 13580.00   13580.00  13580.00  13580.00  13580.00  13580.00 13518.00
# mean      2.94 1075684.08     10.14   3105.30      2.91      1.53     1.61
# std       0.96  639310.72      5.87     90.68      0.97      0.69     0.96
# min       1.00   85000.00      0.00   3000.00      0.00      0.00     0.00
# 25%       2.00  650000.00      6.10   3044.00      2.00      1.00     1.00
# 50%       3.00  903000.00      9.20   3084.00      3.00      1.00     2.00
# 75%       3.00 1330000.00     13.00   3148.00      3.00      2.00     2.00
# max      10.00 9000000.00     48.10   3977.00     20.00      8.00    10.00
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# count  13580.00       7130.00    8205.00   13580.00    13580.00       13580.00
# mean     558.42        151.97    1964.68     -37.81      145.00        7454.42
# std     3990.67        541.01      37.27       0.08        0.10        4378.58
# min        0.00          0.00    1196.00     -38.18      144.43         249.00
# 25%      177.00         93.00    1940.00     -37.86      144.93        4380.00
# 50%      440.00        126.00    1970.00     -37.80      145.00        6555.00
# 75%      651.00        174.00    1999.00     -37.76      145.06       10331.00
# max   433014.00      44515.00    2018.00     -37.41      145.53       21650.00

# %% [markdown]
# Se cuentan los registros de las variables numéricas para tener nocion de la cantidad de datos faltantes respecto del total

# %%
df_melb.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# 'BuildingArea' y 'YearBuilt' tienen aproximadamente la mitad de los datos totales, lo cual van a ser descartadas para este primer analisis, mientras que 'Car' no representa una falta significativa

# %% [markdown]
# Para la elección de variables cuantitativas utilizaremos el coeficiente de correlación de Pearson y para elección de variables categóricas utilizaremos una medida denominada Razón de correlación.

# %% [markdown]
# 1. **Coeficiente de correlación de Pearson**
#
#     Nos da una medida de asociación lineal entre variables numéricas. Toma valores en un rango entre $-1$ y $1$ y, formalmente, deberíamos diferenciar su definición dependiendo si estamos calculándolo sobre una población o sobre una muestra (que es el que utilizaremos en la mayoría de los casos).
#
#     El coeficiente de correlación de Pearson cuando se aplica a una **población**  se representa por la letra griega $\rho$. Dado un par de variables aleatorias $(X, Y)$, el coeficiente de correlación poblacional de Pearson (también denotado por $\rho_{X, Y}$ ) se define como
#     $$
#     \rho_{X, Y}=\frac{\sigma_{X Y}}{\sigma_{X} \sigma_{Y}}=\frac{\operatorname{Cov}(X, Y)}{\sqrt{\operatorname{Var}(X) \operatorname{Var}(Y)}}
#     $$
#
#     Donde $\sigma_{X Y}$ es la covarianza de $(X, Y)$, $\sigma_{X}$ es la desviación estándar de la variable $X$ y $\sigma_{Y}$ es la desviación estándar de la variable $Y$
#
#     El coeficiente de correlación de Pearson cuando es aplicado a una **muestra**, se denota por $r_{x y}$. Dados $n$ pares de datos $\left\{\left(x_{i}, y_{i}\right)\right\}_{i=1}^{n}$, se define el coeficiente de correlación muestral de Pearson como
# $$
# r_{x y}=\frac{\sum_{i=1}^{n}\left(x_{i}-\bar{x}\right)\left(y_{i}-\bar{y}\right)}{\sqrt{\sum_{i=1}^{n}\left(x_{i}-\bar{x}\right)^{2}} \sqrt{\sum_{i=1}^{n}\left(y_{i}-\bar{y}\right)^{2}}}
# $$
#
#     Donde $n$ es el tamaño de la muestra, $x_{i}, y_{i}$ son puntos muestrales individuales indexados con $i$ y $\bar{x}$ denota la media muestral definida por $\bar{x}=\frac{1}{n} \sum_{i=1}^{n} x_{i}$ (análogamente para $\bar{y}$ ).
#
#
#
#
#
# 2. **Razón de correlación** (a menudo marcada con la letra griega $\eta$ )
#
#     Es un medida que nos permite cuantificar la relación entre la variable cuantitativa continua que queremos predecir, es decir Price y las variables categóricas que hemos elegido. La Razón de Correlación trabaja con una variable dependiente, que sería la cuantitativa, y una variable independiente, la cual pasaría a ser la categórica. Entonces, la relación se establece entre una variable independiente y una dependiente, lo cual  implica que la influencia de “X” sobre “Y” no siempre será la misma que la influencia de “Y” sobre “X”.
#
#     Matemáticamente, se define como la varianza ponderada de la media de cada categoría dividida por la varianza de todas las muestras; esto es, la Razón de Correlación responde a la siguiente pregunta: dado un número continuo, ¿qué tan bien puedes saber a qué categoría pertenece?. La salida de $\eta$ está en el rango de $[0,1]$.
#
#     El límite $\eta=0$ representa el caso especial de la no dispersión entre la medias de las diferentes categorías (se refiere al caso sin dispersión en las categorías que contribuyen a la dispersión global), mientras $\eta=1$ se refiere a la no dispersión dentro de las respectivas categorias. Para $\eta=1$ la dispersión de la muestra global se debe únicamente a la dispersión entre las categorías y en absoluto debido a la dispersión dentro de las categorías individuales.
#
#     Para calcular este coeficiente utilizaremos la librería Dython$^{(2)}$, específicamente el módulo llamado 'nominal'$^{(3)}$ .
#
#
# (1) https://towardsdatascience.com/the-search-for-categorical-correlation-a1cf7f1888c9
#
# (2) https://github.com/shakedzy/dython
#
# (3) http://shakedzy.xyz/dython/modules/nominal/

# %% [markdown]
# #### Análisis de la razón de correlación

# %% [markdown]
# Primero se analiza la razón de correlación para la elección de variables categóricas, para esto es necesario instalar [dython](https://github.com/shakedzy/dython) para facilitar el análisis

# %%
#!pip install git+https://github.com/shakedzy/dython.git
#!pip install matplotlib==3.1.1

# %%
#from dython.nominal import associations

# %% [markdown]
# Se calcula la razón de correlacion entre las variables categóricas y 'Price'

# %%
associations(df_melb[categorical+['Postcode', 'Price']], nom_num_assoc='correlation_ratio', figsize=(12, 12))
# Out:
# {'corr':              Suburb  Address  Type  Method  SellerG  Date  CouncilArea  \
#  Suburb         1.00     0.13  0.32    0.15     0.26  0.06         0.87
#  Address        0.13     1.00  0.11    0.00     0.08  0.02         0.08
#  Type           0.32     0.11  1.00    0.06     0.20  0.12         0.26
#  Method         0.15     0.00  0.06    1.00     0.15  0.05         0.11
#  SellerG        0.26     0.08  0.20    0.15     1.00  0.05         0.41
#  Date           0.06     0.02  0.12    0.05     0.05  1.00         0.19
#  CouncilArea    0.87     0.08  0.26    0.11     0.41  0.19         1.00
#  Regionname     0.99     0.10  0.15    0.08     0.50  0.12         0.74
#  Postcode       1.00     1.00  0.03    0.04     0.60  0.18         0.78
#  Price          0.56     1.00  0.41    0.11     0.48  0.16         0.43
#
#               Regionname  Postcode  Price
#  Suburb             0.99      1.00   0.56
#  Address            0.10      1.00   1.00
#  Type               0.15      0.03   0.41
#  Method             0.08      0.04   0.11
#  SellerG            0.50      0.60   0.48
#  Date               0.12      0.18   0.16
#  CouncilArea        0.74      0.78   0.43
#  Regionname         1.00      0.71   0.36
#  Postcode           0.71      1.00   0.11
#  Price              0.36      0.11   1.00  ,
#  'ax': <Axes: >}

# %% [markdown]
# En el caso del coeficiente $\eta$, se toma en cuenta la magnitud del resultado para indicar la proporción en la que una variable X explica la varianza en una variable Y, y se define en un rango que va de 0 a 1, siendo:
#
# *	$0-0,3$ correlación baja.
#
# *	$0,4-0,6$ correlación media.
#
# *	$0,7-1$ correlación alta.
#
# **En base a lo expuesto anteriormente, miramos los valores de $\eta$ mayores a $0.4$**
#
# $\eta(\text{Price},\text{Suburb})= 0.56$
#
# $\eta(\text{Price},\text{Address})= 1$
#
# $\eta(\text{Price},\text{Type})= 0.41$
#
# $\eta(\text{Price},\text{SellerG})= 0.48$
#
# $\eta(\text{Price},\text{CouncilArea})= 0.43$
#
# y optamos por las siguientes variables categóricas para la predicción del valor de la propiedad en Melbourne:
#
# - Address.
#
# - Suburb.
#
# - SellerG.
#
# - CouncilArea.
#
# - Type.

# %% [markdown]
# Se guardan las columnas de interes y se eliminan el resto de las columnas

# %%
interesting_columns_categ = ['Address', 'Suburb', 'SellerG', 'CouncilArea', 'Type']

# %%
df_melb_f= df_melb.copy()

# %%
columns_to_drop = ['Postcode', 'Suburb', 'Address', 'Type', 'Method', 'CouncilArea', 'Regionname', 'SellerG']
df_melb_f = df_melb.drop(columns_to_drop, axis=1)

# %% [markdown]
# Ahora se analiza la razón de correlación de las variables numéricas

# %% [markdown]
# Se convierte la fecha a un valor tipo ```int```

# %%
df_melb_f['Date'] = pd.to_datetime(df_melb_f['Date'], format='%d/%m/%Y')

# %%
mask = np.triu(np.ones_like(df_melb_f.corr(), dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(round(df_melb_f.corr(),3), mask=mask, cmap=cmap,annot=True, center=0,
            square=True, linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# BuildingArea tiene  un coeficiente de correlación $r=0.5$ con la variable Landsize, que si bien es un grado de asociación moderado, decidimos conservar dentro de las columnas relevantes a BuildingArea a pesar de que ésta tiene un $47.49\%$ de valores faltantes (esta variable es necesaria conservarla para la segunda parte del entregable).
#
# Aclarado lo anterior, miraremos los coeficientes de correlación muestrales mayores a 0.5 en valor absoluto $(\mid r \mid >0.5)$ y nos quedaremos con solo una variable del par:
#
# - $r(\text{Bedroom2}, \text{rooms})=0.94$
# - $r(\text{Bathroom}, \text{rooms})=0.59$
# - $r(\text{Bathroom}, \text{Bedroom2})=0.58$
#
# Nos quedamos con la variable Rooms; descartamos Bathroom y Bedroom2 .
#
# En resumen, las variables numéricas que vamos a incluir en columnas relevantes serán:
#  - BuildingArea
#  - Rooms
#  - Propertycount
#  - Lattitude
#  - Longtitude
#  - Distance
#  - YearBuilt
#  - Car

# %% [markdown]
# Se actualiza la lista de variables relevantes

# %%
interesting_columns_categ_num=['Address', 'Suburb', 'SellerG', 'CouncilArea',
                               'Type', 'BuildingArea', 'Rooms', 'Propertycount',
                               'Lattitude','Longtitude', 'Distance', 'YearBuilt',
                               'Car']

# %% [markdown]
# Como en la lista de columnas relevantes vamos a incluir a longitud y latitud, consideramos que la variable Address sería redundante en una primera instancia.
#
# Por otro lado, si bien la variable Postcode no fue seleccionada bajo los criteros que ulitizamos, va a ser incluida en las columnas de interés ya que la consigna del punto siguiente nos pide combinar los datos de Melbourne con los de AirBnb utilizando la variable zipcode lo cual se hace necesario considerar a Postcode para hacer dicha operación.
#
# Luego nuestra lista de variables para predecir el valor de una propiedad es la siguiente:

# %%
interesting_columns_melb=['Suburb', 'SellerG', 'CouncilArea', 'Type', 'BuildingArea', 'Rooms',
                          'Propertycount', 'Lattitude','Longtitude', 'Distance', 'YearBuilt', 'Car','Postcode']

# %% [markdown]
# #### Análisis de valores extremos o irrelevantes para la predicción de valores de las propiedades

# %% [markdown]
# - Variable numérica continua **BuildinArea**: por medio de un boxplot podemos visualizar los valores atípicos. Además, en el resumen de variables observamos que BuildinArea tiene un mínimo menor de 0 metros cuadrados lo cual no es posible.

# %%
#deteccion de puntos atípicos
k = 75
percentile_75 = df_melb['BuildingArea'].quantile(k/ 100)
j=25
percentile_25 = df_melb['BuildingArea'].quantile(j/ 100)

RIQ= percentile_75 - percentile_25 #rango intercuartilico
limite_inf= percentile_25 - (1.5*RIQ)
limite_sup= percentile_75 + (1.5*RIQ)
print(limite_inf, limite_sup)
# Out:
# -28.5 295.5

# %% [markdown]
# Notemos que el límite inferior del bigote es $-28.5$, un valor que no pertenece a la muestra, por lo que el valor $0$ quedará como valor de dicho límite. Por este motivo consideramos utilizar a los percentiles como método para remover los outliers.
#
# En este caso consideraremos como outliers los valores de BuildingArea por debajo  del percentil $1\%$  y los valores por encima del percentil $95\%$.
#
# Decidimos utilizar estos valores porque son los aceptables para que no se considere al valor $0$ como parte de la muestra y para que la cantidad de outliers por arriba no sea excesivo.

# %%
df_melb_f.columns
# Out:
# Index(['Rooms', 'Price', 'Date', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount'],
#       dtype='object')

# %%
max_limit = df_melb_f['BuildingArea'].quantile(.93)
min_limit= df_melb_f['BuildingArea'].quantile(.1)
data = df_melb_f[~((df_melb_f['BuildingArea'] > max_limit) | (df_melb_f['BuildingArea'] < min_limit))]['BuildingArea']
sns.boxplot(x=data)
plt.title('Distribución de la variable BuildingArea')
plt.show()

# %%
mask_b=~((df_melb['BuildingArea'] > max_limit) | (df_melb['BuildingArea'] < min_limit))
df_melb[mask_b].BuildingArea.isna().sum()
# Out:
# 6450

# %% [markdown]
# - Variable numérica discreta **Rooms**: por medio de un gráfico de barras podemos visualizar si existe alguna cantidad atípica para el número de habitaciones. Por otro lado, en el resumen de variables que Rooms posee un máximo de 10 habitaciones. Nos enfocaremos también en esta observación.

# %%
sns.countplot(x="Rooms", data=df_melb)
plt.title('Distribución de la variable Rooms')
plt.show()

# %% [markdown]
# Tabla de frecuencias expresada como porcentaje

# %%
df_melb.Rooms.value_counts(1)*100
# Out:
# Rooms
# 3    43.31
# 2    26.86
# 4    19.79
# 1     5.01
# 5     4.39
# 6     0.49
# 7     0.07
# 8     0.06
# 10    0.01
# Name: proportion, dtype: float64

# %% [markdown]
# Con el gráfico y la ayuda de la tabla de frecuencias relativas, decidimos que la cantidad de viviendas que tengan mas de 5 habitaciones (representan menos del 1% del total) serán consideradas irrelevantes.

# %%
mask_r=df_melb['Rooms'] < 6

# %% [markdown]
# * Variable numérica discreta **Car**: analizaremos los valores atípicos de esta variable con la misma lógica con la que trabajamos 'Rooms'. Primero medio de un gráfico de barrasvisualizamos si existe alguna cantidad atípica para el número de cocheras. Además en el resumen de variables numéricas vemos que 'Car' posee un máximo de 10 cocheras lo cual será un punto a analizar.

# %%
sns.countplot(x="Car", data=df_melb)
plt.title('Distribución de la variable Car')
plt.show()

# %%
df_melb.Car.value_counts(1)*100
# Out:
# Car
# 2.00    41.36
# 1.00    40.75
# 0.00     7.59
# 3.00     5.53
# 4.00     3.74
# 5.00     0.47
# 6.00     0.40
# 8.00     0.07
# 7.00     0.06
# 10.00    0.02
# 9.00     0.01
# Name: proportion, dtype: float64

# %% [markdown]
# Con el gráfico y la ayuda de la tabla de frecuencias relativas, decidimos que la cantidad de viviendas que tengan mas de 4 cocheras (representan menos del 1% del total) serán consideradas irrelevantes.

# %%
mask_c=df_melb['Car'] < 5

# %% [markdown]
# Variable numérica continua **Distance**: con esta variable sucede lo mismo que con Landsize, tiene un mínimo de $0$ lo cual podría considerarse atípico por tratarse de una distancia al centro de la ciudad de Melbourne. Sin embargo, CBD hace referencia a la región céntrica, en Wikipedia se puede encontrar la siguiente información${^{(1)}}$:
#
# "El distrito central de negocios de Melbourne (también conocido coloquialmente simplemente como " La ciudad " o " El CBD ") es el centro de la ciudad y el área urbana principal de la ciudad de Melbourne , Victoria, Australia , centrada en Hoddle Grid , la más antigua parte de la ciudad trazada en 1837, e incluye sus márgenes."
#
# Luego podemos considerar que hay viviendas dentro de esta región céntrica lo cual tendría lógica ese valor mínimo en el dataset.
#
# (1) https://en.wikipedia.org/wiki/Melbourne_central_business_district

# %%
#Conjunto de datos final de Melbourne
melb_1=df_melb.copy()
melb_1=melb_1[interesting_columns_melb]
mask= mask_b & mask_r & mask_c
df_melb_final=melb_1[mask]

# %% [markdown]
# El DataFrame que obtenemos luego de los análisis anteriores es el siguiente

# %%
df_melb_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12137 entries, 0 to 13579
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         12137 non-null  object
#  1   SellerG        12137 non-null  object
#  2   CouncilArea    10946 non-null  object
#  3   Type           12137 non-null  object
#  4   BuildingArea   5825 non-null   float64
#  5   Rooms          12137 non-null  int64
#  6   Propertycount  12137 non-null  float64
#  7   Lattitude      12137 non-null  float64
#  8   Longtitude     12137 non-null  float64
#  9   Distance       12137 non-null  float64
#  10  YearBuilt      6987 non-null   float64
#  11  Car            12137 non-null  float64
#  12  Postcode       12137 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
df_melb_final.isnull().mean()*100
# Out:
# Suburb           0.00
# SellerG          0.00
# CouncilArea      9.81
# Type             0.00
# BuildingArea    52.01
# Rooms            0.00
# Propertycount    0.00
# Lattitude        0.00
# Longtitude       0.00
# Distance         0.00
# YearBuilt       42.43
# Car              0.00
# Postcode         0.00
# dtype: float64

# %%
df_melb_final.head()
# Out:
#        Suburb SellerG CouncilArea Type  BuildingArea  Rooms  Propertycount  \
# 0  Abbotsford  Biggin       Yarra    h           NaN      2        4019.00
# 1  Abbotsford  Biggin       Yarra    h         79.00      2        4019.00
# 2  Abbotsford  Biggin       Yarra    h        150.00      3        4019.00
# 3  Abbotsford  Biggin       Yarra    h           NaN      3        4019.00
# 4  Abbotsford  Nelson       Yarra    h        142.00      4        4019.00
#
#    Lattitude  Longtitude  Distance  YearBuilt  Car  Postcode
# 0     -37.80      145.00      2.50        NaN 1.00   3067.00
# 1     -37.81      144.99      2.50    1900.00 0.00   3067.00
# 2     -37.81      144.99      2.50    1900.00 0.00   3067.00
# 3     -37.80      145.00      2.50        NaN 1.00   3067.00
# 4     -37.81      144.99      2.50    2014.00 2.00   3067.00

# %% [markdown]
# ### 2.2 Combinacion de los _Dataset_
#
# #### 2.2.1 Columnas de interes

# %% [markdown]
# Se vuelve a cargar el _Dataset_ con los datos de los Airbnb ya que el primero habia sido filtrado para trabajar más comodo y ahora necesitamos conocer todas las columnas y elegir algunas otras

# %%
df_airbnb_f = pd.read_csv('../Data/cleansed_listings_dec18.csv')
# Out:
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\492189723.py:1: DtypeWarning: Columns (35,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_airbnb_f = pd.read_csv('../Data/cleansed_listings_dec18.csv')

# %%
df_airbnb_f.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'neighborhood_overview', 'notes', 'transit',
#        'access', 'interaction', 'house_rules', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighborhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price',
#        'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'license',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
interesting_cols = ['street', 'neighborhood', 'city', 'suburb', 'state',
                    'zipcode', 'price', 'weekly_price', 'monthly_price',
                    'latitude', 'longitude']

# %% [markdown]
# Se agregan las siguientes columnas

# %%
interesting_cols.append('bathrooms')
interesting_cols.append('bedrooms')

# %%
interesting_cols
# Out:
# ['street',
#  'neighborhood',
#  'city',
#  'suburb',
#  'state',
#  'zipcode',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'latitude',
#  'longitude',
#  'bathrooms',
#  'bedrooms']

# %%
columnas_relevantes=['price', 'weekly_price',  'monthly_price', 'zipcode']

# %%
df_airbnb_f = pd.read_csv('../Data/cleansed_listings_dec18.csv', usecols=interesting_cols)
# Out:
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\1772399083.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_airbnb_f = pd.read_csv('../Data/cleansed_listings_dec18.csv', usecols=interesting_cols)

# %%
df_airbnb_f.columns
# Out:
# Index(['street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
#        'latitude', 'longitude', 'bathrooms', 'bedrooms', 'price',
#        'weekly_price', 'monthly_price'],
#       dtype='object')

# %%
df_airbnb_f.zipcode.head(5)
# Out:
# 0    3105
# 1    3057
# 2    3182
# 3    3071
# 4    3183
# Name: zipcode, dtype: object

# %%
df_airbnb_f['zipcode'] = pd.to_numeric(df_airbnb_f.zipcode, errors='coerce') #If 'coerce', then invalid parsing will be set as NaN.

# %%
df_airbnb_f['zipcode'] = df_airbnb_f.zipcode.fillna(0).astype('int')

# %% [markdown]
# Observamos la distribución de la variable price, monthly_price y weekly_price.

# %%
fig, axes = plt.subplots(nrows=3, figsize=(10,30))
columnas_price=['price', 'weekly_price',  'monthly_price']

for nombre, eje in zip(columnas_price, axes):
    sns.distplot( x=df_airbnb_f[nombre], ax=eje)
    eje.set_title(nombre)

plt.show()
# Out:
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\1856570404.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x=df_airbnb_f[nombre], ax=eje)
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\1856570404.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x=df_airbnb_f[nombre], ax=eje)
# C:\Users\enzom\AppData\Local\Temp\ipykernel_14996\1856570404.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( x=df_airbnb_f[nombre], ax=eje)

# %% [markdown]
# Como las variables asociadas a price tienen un insesgamiento hacia la derecha, vamos a utilizar la mediana de la muestra como criterio para transformar dichos datos. Entonces, agrupamos por zipcode y obtenemos la mediana de price, weekly_price y monthly_price por cada subgrupo.

# %%
airbnb_prices_by_zipcode = df_airbnb_f[columnas_relevantes].groupby('zipcode').agg(airbnb_price_median=('price', 'median'), airbnb_weekly_price_median=('weekly_price', 'median'), airbnb_monthly_price_median=('monthly_price', 'median')).reset_index()

# %%
airbnb_prices_by_zipcode[:10]
# Out:
#    zipcode  airbnb_price_median  airbnb_weekly_price_median  \
# 0        0               120.00                      780.00
# 1     2010                40.00                         NaN
# 2     2134                50.00                         NaN
# 3     2582               104.00                         NaN
# 4     3000               129.00                      857.00
# 5     3001               132.50                         NaN
# 6     3002               130.00                      775.00
# 7     3003               120.00                      728.00
# 8     3004               130.00                     1000.00
# 9     3006               150.00                     1099.50
#
#    airbnb_monthly_price_median
# 0                      3300.00
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                      3469.00
# 5                          NaN
# 6                      3300.00
# 7                      2500.00
# 8                      3895.00
# 9                      3955.00

# %% [markdown]
# Vamos a inspeccionar cuáles son los registros más altos por zipcode.

# %%
num_registros_zipcode=df_airbnb_f.groupby('zipcode').agg(cantidad_reg=('zipcode','count')).reset_index()
num_registros_zipcode.sort_values(by='cantidad_reg', ascending=True)
# Out:
#      zipcode  cantidad_reg
# 247    30122             1
# 204     3785             1
# 230     3912             1
# 200     3778             1
# 188     3753             1
# ..       ...           ...
# 8       3004           728
# 117     3141           881
# 155     3182          1135
# 9       3006          1268
# 4       3000          3367
#
# [248 rows x 2 columns]

# %% [markdown]
# Consideramos que todos los zipcode con registros mayores a 1 son significativos para enriquecer la base de datos de Melbourne.

# %%
zip_1=num_registros_zipcode[num_registros_zipcode.cantidad_reg>1][['zipcode']]
zip_1.reset_index(drop=True)
# Out:
#      zipcode
# 0          0
# 1       3000
# 2       3001
# 3       3002
# 4       3003
# ..       ...
# 223     3975
# 224     3976
# 225     3977
# 226     3978
# 227     3980
#
# [228 rows x 1 columns]

# %% [markdown]
# filtramos los datos de airbnb_prices_by_zipcode por aquellos zipcode que tengan más de 1 registro.

# %%
b=airbnb_prices_by_zipcode.reset_index(drop=True)
airbnb_prices_by_zipcode_final=b.loc[b['zipcode'].isin(zip_1['zipcode'])]
airbnb_prices_by_zipcode_final.zipcode.describe() #controlamos que los valores de zipcode estén en el rango elegido
# Out:
# count    228.00
# mean    3246.88
# std      363.90
# min        0.00
# 25%     3069.50
# 50%     3141.50
# 75%     3202.50
# max     3980.00
# Name: zipcode, dtype: float64

# %%
airbnb_prices_by_zipcode_final=airbnb_prices_by_zipcode_final.reset_index(drop=True)

# %% [markdown]
# #### 2.2.2 Union por zipcode

# %%
merged_sales_df = df_melb_final.merge(
    airbnb_prices_by_zipcode_final, how='left',
    left_on='Postcode', right_on='zipcode'
)
merged_sales_df.sample(5)
# Out:
#               Suburb   SellerG   CouncilArea Type  BuildingArea  Rooms  \
# 4227  Port Melbourne  Marshall  Port Phillip    u           NaN      2
# 9553   Glen Waverley     Barry        Monash    h           NaN      3
# 4031  Oakleigh South    Buxton        Monash    h           NaN      3
# 4537       Reservoir    Nelson       Darebin    h         92.00      2
# 4393         Preston      Love       Darebin    h        147.00      3
#
#       Propertycount  Lattitude  Longtitude  Distance  YearBuilt  Car  \
# 4227        8648.00     -37.84      144.93      3.80        NaN 1.00
# 9553       15321.00     -37.88      145.17     16.70        NaN 2.00
# 4031        3692.00     -37.91      145.09     14.70        NaN 4.00
# 4537       21650.00     -37.71      145.01     11.20    1970.00 2.00
# 4393       14577.00     -37.74      145.01      8.80    1965.00 1.00
#
#       Postcode  zipcode  airbnb_price_median  airbnb_weekly_price_median  \
# 4227   3207.00  3207.00               152.00                     1100.00
# 9553   3150.00  3150.00                80.00                      405.00
# 4031   3167.00  3167.00                46.00                         NaN
# 4537   3073.00  3073.00                55.00                      335.00
# 4393   3072.00  3072.00                71.00                      450.00
#
#       airbnb_monthly_price_median
# 4227                      3600.00
# 9553                      1490.50
# 4031                          NaN
# 4537                      1177.50
# 4393                      1300.00

# %% [markdown]
# Se elimina la columna 'zipcode' ya que es igual a 'Postcode'

# %%
merged_sales_df=merged_sales_df.drop('zipcode', axis=1)

# %%
merged_sales_df.isnull().mean()*100
# Out:
# Suburb                         0.00
# SellerG                        0.00
# CouncilArea                    9.81
# Type                           0.00
# BuildingArea                  52.01
# Rooms                          0.00
# Propertycount                  0.00
# Lattitude                      0.00
# Longtitude                     0.00
# Distance                       0.00
# YearBuilt                     42.43
# Car                            0.00
# Postcode                       0.00
# airbnb_price_median            0.17
# airbnb_weekly_price_median     6.72
# airbnb_monthly_price_median    9.69
# dtype: float64

# %%
merged_sales_df.columns, merged_sales_df.shape
# Out:
# (Index(['Suburb', 'SellerG', 'CouncilArea', 'Type', 'BuildingArea', 'Rooms',
#         'Propertycount', 'Lattitude', 'Longtitude', 'Distance', 'YearBuilt',
#         'Car', 'Postcode', 'airbnb_price_median', 'airbnb_weekly_price_median',
#         'airbnb_monthly_price_median'],
#        dtype='object'),
#  (12137, 16))

# %% [markdown]
# #### 2.2.3 Otras variables para combinar los datos

# %% [markdown]
# Para predecir precios de viviendas o de cualquier entidad a la cual se le pueda asociar datos con connotación geográfica es de importacia pensar en métodos de geolocalización.
#
# La geolocalización es cada vez más habitual en la analítica de negocio e inteligencia comercial y para utilizarla debemos poder ubicar el objeto de estudio (o nuestra unidad experimental) en un mapa. Esta estrategia permite estudiar el problema en un contexto más amplio y preciso, es decir, si un cliente solo brinda su Código Postal (CP) o su Provincia, su coordenada geográfica será el centroide del CP o de la provincia, y tendrá nivel de precisión bajo; en cambio, si otro cliente indica una dirección completa y válida, sus coordenadas estarán en el número de vía y, por tanto, tendrá un nivel de precisión alto.
#
# Una de las ventajas de contar con la geolocalización es que podemos aportar información externa a nuestra base de datos. Al momento de geolocalizar una vivienda, podemos cualificar su entorno: podemos saber el nivel de renta, precio de las propiedades circundantes, la distancia a los principales centros comerciales o de educación, etc. Así, el enlace o cruce con otra información permite enriquecer la representación de la realidad que se busca.
#
#
# Para poder sacar provecho de esta tecnología es necesario trabajar con coordenadas geográficas, es decir, latitud y longitud. Bajo este enfonque sería interesante poder combinar ambos dataset, Melbourne y AirBnB, por medio de las variables Lattitude y Longtitude.
#
# Ambas variables serían adecuadas si pudieramos validar su consistencia y homogeneidad, por lo cual podríamos suponer que contamos con API's de georreferenciación que nos ayuden a constatarlo.

# %%
pd.options.display.float_format = '{:.6f}'.format

# %%
df_melb[['Lattitude', 'Longtitude']]
# Out:
#        Lattitude  Longtitude
# 0     -37.799600  144.998400
# 1     -37.807900  144.993400
# 2     -37.809300  144.994400
# 3     -37.796900  144.996900
# 4     -37.807200  144.994100
# ...          ...         ...
# 13575 -37.905620  145.167610
# 13576 -37.859270  144.879040
# 13577 -37.852740  144.887380
# 13578 -37.859080  144.892990
# 13579 -37.811880  144.884490
#
# [13580 rows x 2 columns]

# %%
df_airbnb[['latitude', 'longitude']]
# Out:
#         latitude  longitude
# 0     -37.772684 145.092133
# 1     -37.766505 144.980736
# 2     -37.859755 144.977369
# 3     -37.758971 144.989228
# 4     -37.864530 144.992238
# ...          ...        ...
# 22890 -37.802415 144.962967
# 22891 -37.705095 144.574474
# 22892 -37.875252 145.162757
# 22893 -37.827795 144.954987
# 22894 -37.805186 144.962399
#
# [22895 rows x 2 columns]

# %%
print('Lat.\tMedia df_melb:\t\t', df_melb.Lattitude.mean())
print('Lat.\tMedia df_airbnb:\t', df_airbnb.latitude.mean())
print('Long.\tMedia df_melb:\t\t', df_melb.Longtitude.mean())
print('Long.\tMedia df_airbnb:\t', df_airbnb.longitude.mean())
# Out:
# Lat.	Media df_melb:		 -37.80920273343152
# Lat.	Media df_airbnb:	 -37.826827302354666
# Long.	Media df_melb:		 144.99521618777615
# Long.	Media df_airbnb:	 145.00845712462984

# %%
print('Desv. std. df_melb:\t', df_melb.Lattitude.std())
print('Desv. std. df_airbnb:\t', df_airbnb.latitude.std())
print('Desv. std. df_melb:\t', df_melb.Longtitude.std())
print('Desv. std. df_airbnb:\t', df_airbnb.longitude.std())
# Out:
# Desv. std. df_melb:	 0.07925982260355424
# Desv. std. df_airbnb:	 0.06674714152684505
# Desv. std. df_melb:	 0.10391556140737532
# Desv. std. df_airbnb:	 0.12771062442421346

# %% [markdown]
# Se observa que presentan valores muy miliares entre si, con la diferencia de algunos decimales. Para poder unir ambos _Dataset_ se deberia:
#
# - Investigar como se mide Latitud y Longitud
# - Tomar un criterio para redondear los valores

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(data=df_melb, x='Lattitude', y='Longtitude', label='df_melb', alpha=0.9, color='darkred')
sns.scatterplot(data=df_airbnb, x='latitude', y='longitude', label='df_airbnb', alpha=0.3, color='tomato')
#sns.kdeplot(data=df_melb, x='Lattitude', y='Longtitude', levels=5, cmap='Blues', linewidths=1)
#sns.kdeplot(data=df_airbnb, x='latitude', y='longitude', levels=5, cmap='Oranges', linewidths=1)

plt.xlabel('Latitud')
plt.ylabel('Longitud')
plt.legend()
plt.show()

# %% [markdown]
# El grafico muestra una gran similud en la distribucion de valores para ambas variables de los dos _Dataset_

# %% [markdown]
# ## Ejercicio 3:
#
# Crear y guardar un nuevo conjunto de datos con todas las transformaciones realizadas anteriormente.

# %%
merged_sales_df.to_csv("melb_data_extended.csv", index=None)
#files.download('melb_data_extended.csv')

# %% [markdown]
# ## Ejercicios opcionales:
#
# 1. Armar un script en python (archivo .py) [ETL](https://towardsdatascience.com/what-to-log-from-python-etl-pipelines-9e0cfe29950e) que corra los pasos de extraccion, transformacion y carga, armando una funcion para cada etapa del proceso y luego un main que corra todos los pasos requeridos.
#
# 2. Armar un DAG en [Apache Airflow](https://airflow.apache.org/docs/apache-airflow/stable/tutorial.html) que corra el ETL.

# %% [markdown]
# ### 1. Script en Python ETL

# %% [markdown]
# Se crea el archivo de configuración, se importan varios módulos necesarios, establece la configuración del registro (logging), define tres funciones principales ```extract```, ```transform``` y ```load```, y luego llama a la función principal ```main()``` para ejecutar el proceso ETL

# %%
# %%writefile etlConfig.ini
# ##ETL jobs Parameters
#
# [ETL_Log_Job] ##Job name
# Job_Name = etl_log_job.py
# LogName = etl_log_job.log
# TgtConnection = Customers.db
# SrcConnection = Customers.db
# MelbourneSrcObject = https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv
# AirbnbSrcObjetc = /content/drive/My Drive/Colab Notebooks/Data/cleansed_listings_dec18.csv
# TgtObject = customer
# ##Add more job details as needed
# Out:
# Writing etlConfig.ini

# %%
# %%writefile ETL_script.py
import logging.config
import time
import psutil
import configparser
import sqlite3
import pandas as pd

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

config = configparser.ConfigParser()
config.read('etlConfig.ini')
JobConfig = config['ETL_Log_Job']

formatter = logging.Formatter('%(levelname)s:  %(asctime)s:  %(process)s:  %(funcName)s:  %(message)s')
stream_handler = logging.StreamHandler()
file_handler = logging.FileHandler(JobConfig['LogName'])
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

def extract():
    logger.info('Start Extract Session')
    #logger.info('Source Filename: {}'.format(JobConfig['SrcObject']))
    try:
        melb_df = pd.read_csv(JobConfig['MelbourneSrcObject'])
        airbnb_df = pd.read_csv(JobConfig['AirbnbSrcObjetc'], low_memory=False)
        logger.info('Records count in Melbourne source file: {}'.format(len(melb_df.index)))
        logger.info('Records count in Airbnb source file: {}'.format(len(airbnb_df.index)))
    except ValueError as e:
        logger.error(e)
        return
    logger.info("Read completed")
    return melb_df, airbnb_df

def transform(melb_df, airbnb_df):
    try:
        airbnb_df['zipcode'] = pd.to_numeric(airbnb_df.zipcode, errors='coerce')
        airbnb_df['zipcode'] = airbnb_df.zipcode.fillna(0).astype('int')

        airbnb_grouped = airbnb_df.groupby('zipcode').agg(
            airbnb_price_mean=('price', 'mean'),
            airbnb_record_count=('zipcode', 'count'),
            airbnb_weekly_price_mean=('weekly_price', 'mean'),
            airbnb_monthly_price_mean=('monthly_price', 'mean')
            ).reset_index()

        melb_df['Postcode'] = melb_df['Postcode'].astype(int)
        merged_df = pd.merge(melb_df, airbnb_grouped, left_on='Postcode', right_on='zipcode', how='left')

        logger.info('Transformation completed, data ready to load')

    except Exception as e:
        logger.error(e)
        return None

    return merged_df

def load(ldf):
    logger.info('Start Load Session')
    try:
        conn = sqlite3.connect(JobConfig['TgtConnection'])
        cursor = conn.cursor()
        logger.info('Connection to {} database established'.format(JobConfig['TgtConnection']))
    except Exception as e:
        logger.error(e)
        return

    #Load dataframe to table
    try:
        ldf.to_sql(JobConfig['TgtObject'], conn, if_exists='replace', index=False)
        logger.info("Data Loaded into target table: {}".format(JobConfig['TgtObject']))
    except Exception as e:
        logger.error(e)
        return
    conn.commit()
    logger.info("Data Loaded into target table: {}".format(JobConfig['TgtObject']))
    return

def main():
    start = time.time()

    ##Extract
    start1 = time.time()
    melb_df, airbnb_df = extract()
    end1 = time.time() - start1
    logger.info('Extract CPU usage {}%'.format(psutil.cpu_percent()))
    logger.info("Extract function took : {} seconds".format(end1))

    ##Transformation
    start2 = time.time()
    ldf = transform(melb_df, airbnb_df)
    end2 = time.time() - start2
    logger.info('Transform CPU usage {}%'.format(psutil.cpu_percent()))
    logger.info("Transformation took : {} seconds".format(end2))

    ##Load
    start3 = time.time()
    load(ldf)
    end3 = time.time() - start3
    logger.info('Load CPU usage {}%'.format(psutil.cpu_percent()))
    logger.info("Load took : {} seconds".format(end3))
    end = time.time() - start
    logger.info("ETL Job took : {} seconds".format(end))
    logger.info('Session Summary')
    logger.info('RAM memory {}% used:'.format(psutil.virtual_memory().percent))
    logger.info('CPU usage {}%'.format(psutil.cpu_percent()))
    print("multiple threads took : {} seconds".format(end))

if __name__=="__main__":
    logger.info('ETL Process Initialized')
    main()
# Out:
# Writing ETL_script.py

# %% [markdown]
# Luego de crear el archivo ```ETL_script.py```, se ejecuta mediante el comando ```%run```

# %%
# %run ETL_script.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Github\diplodatos\1_Materias\ETL_script.py:111
#     109 if __name__=="__main__":
#     110     logger.info('ETL Process Initialized')
# --> 111     main()
#
# File ~\Github\diplodatos\1_Materias\ETL_script.py:84, in main()
#      82 ##Extract
#      83 start1 = time.time()
# ---> 84 melb_df, airbnb_df = extract()
#      85 end1 = time.time() - start1
#      86 logger.info('Extract CPU usage {}%'.format(psutil.cpu_percent()))
#
# File ~\Github\diplodatos\1_Materias\ETL_script.py:26, in extract()
#      24 try:
#      25     melb_df = pd.read_csv(JobConfig['MelbourneSrcObject'])
# ---> 26     airbnb_df = pd.read_csv(JobConfig['AirbnbSrcObjetc'], low_memory=False)
#      27     logger.info('Records count in Melbourne source file: {}'.format(len(melb_df.index)))
#      28     logger.info('Records count in Airbnb source file: {}'.format(len(airbnb_df.index)))
#
# File c:\Users\enzom\miniconda3\envs\env_1\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\enzom\miniconda3\envs\env_1\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\enzom\miniconda3\envs\env_1\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\enzom\miniconda3\envs\env_1\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\enzom\miniconda3\envs\env_1\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Data/cleansed_listings_dec18.csv'

# %% [markdown]
# Finalmente se descar el script y el archivo de configuración

# %%
files.download('ETL_script.py')
files.download('etlConfig.ini')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 files.download('ETL_script.py')
#       2 files.download('etlConfig.ini')
#
# NameError: name 'files' is not defined

# %% [markdown]
# ### DAG en Apache Airflow

# %% [markdown]
# Se define el flujo de trabajo DAG llamado 'ETL_process'. Este DAG consta de tres tareas: extracción, transformación y carga. Cada tarea se implementa utilizando el operador ```PythonOperator```, que ejecuta una fucion especifica

# %%
#pip install apache-airflow --ignore-installed blinker
# Out:
# Collecting apache-airflow
#   Using cached apache_airflow-2.9.1-py3-none-any.whl (13.3 MB)
# Collecting blinker
#   Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting alembic<2.0,>=1.13.1 (from apache-airflow)
#   Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Collecting argcomplete>=1.10 (from apache-airflow)
#   Using cached argcomplete-3.3.0-py3-none-any.whl (42 kB)
# Collecting asgiref (from apache-airflow)
#   Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting attrs>=22.1.0 (from apache-airflow)
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting colorlog<5.0,>=4.0.2 (from apache-airflow)
#   Using cached colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Collecting configupdater>=3.1.1 (from apache-airflow)
#   Using cached ConfigUpdater-3.2-py2.py3-none-any.whl (34 kB)
# Collecting connexion[flask]<3.0,>=2.10.0 (from apache-airflow)
#   Using cached connexion-2.14.2-py2.py3-none-any.whl (95 kB)
# Collecting cron-descriptor>=1.2.24 (from apache-airflow)
#   Using cached cron_descriptor-1.4.3-py3-none-any.whl (49 kB)
# Collecting croniter>=2.0.2 (from apache-airflow)
#   Using cached croniter-2.0.5-py2.py3-none-any.whl (20 kB)
# Collecting cryptography>=39.0.0 (from apache-airflow)
#   Using cached cryptography-42.0.7-cp39-abi3-manylinux_2_28_x86_64.whl (3.8 MB)
# Collecting deprecated>=1.2.13 (from apache-airflow)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dill>=0.2.2 (from apache-airflow)
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Collecting flask-caching>=1.5.0 (from apache-airflow)
#   Using cached Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Collecting flask-session<0.6,>=0.4.0 (from apache-airflow)
#   Using cached flask_session-0.5.0-py3-none-any.whl (7.2 kB)
# Collecting flask-wtf>=0.15 (from apache-airflow)
#   Using cached flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Collecting flask<2.3,>=2.2 (from apache-airflow)
#   Using cached Flask-2.2.5-py3-none-any.whl (101 kB)
# Collecting fsspec>=2023.10.0 (from apache-airflow)
#   Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Collecting google-re2>=1.0 (from apache-airflow)
#   Using cached google_re2-1.1.20240501-1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (517 kB)
# Collecting gunicorn>=20.1.0 (from apache-airflow)
#   Using cached gunicorn-22.0.0-py3-none-any.whl (84 kB)
# Collecting httpx (from apache-airflow)
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Collecting importlib_metadata>=6.5 (from apache-airflow)
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting itsdangerous>=2.0 (from apache-airflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting jinja2>=3.0.0 (from apache-airflow)
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Collecting jsonschema>=4.18.0 (from apache-airflow)
#   Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Collecting lazy-object-proxy (from apache-airflow)
#   Using cached lazy_object_proxy-1.10.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68 kB)
# Collecting linkify-it-py>=2.0.0 (from apache-airflow)
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Collecting lockfile>=0.12.2 (from apache-airflow)
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting markdown-it-py>=2.1.0 (from apache-airflow)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting markupsafe>=1.1.1 (from apache-airflow)
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting marshmallow-oneofschema>=2.0.1 (from apache-airflow)
#   Using cached marshmallow_oneofschema-3.1.1-py3-none-any.whl (5.7 kB)
# Collecting mdit-py-plugins>=0.3.0 (from apache-airflow)
#   Using cached mdit_py_plugins-0.4.1-py3-none-any.whl (54 kB)
# Collecting methodtools>=0.4.7 (from apache-airflow)
#   Using cached methodtools-0.4.7-py3-none-any.whl
# Collecting opentelemetry-api>=1.15.0 (from apache-airflow)
#   Using cached opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
# Collecting opentelemetry-exporter-otlp (from apache-airflow)
#   Using cached opentelemetry_exporter_otlp-1.24.0-py3-none-any.whl (7.0 kB)
# Collecting packaging>=14.0 (from apache-airflow)
#   Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Collecting pathspec>=0.9.0 (from apache-airflow)
#   Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Collecting pendulum<4.0,>=2.1.2 (from apache-airflow)
#   Using cached pendulum-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
# Collecting pluggy>=1.0 (from apache-airflow)
#   Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Collecting psutil>=4.2.0 (from apache-airflow)
#   Using cached psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Collecting pygments>=2.0.1 (from apache-airflow)
#   Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Collecting pyjwt>=2.0.0 (from apache-airflow)
#   Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting python-daemon>=3.0.0 (from apache-airflow)
#   Using cached python_daemon-3.0.1-py3-none-any.whl (31 kB)
# Collecting python-dateutil>=2.3 (from apache-airflow)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting python-nvd3>=0.15.0 (from apache-airflow)
#   Using cached python_nvd3-0.16.0-py3-none-any.whl
# Collecting python-slugify>=5.0 (from apache-airflow)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Collecting requests<3,>=2.27.0 (from apache-airflow)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting rfc3339-validator>=0.1.4 (from apache-airflow)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rich-argparse>=1.0.0 (from apache-airflow)
#   Using cached rich_argparse-1.4.0-py3-none-any.whl (19 kB)
# Collecting rich>=12.4.4 (from apache-airflow)
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Collecting setproctitle>=1.1.8 (from apache-airflow)
#   Using cached setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sqlalchemy<2.0,>=1.4.36 (from apache-airflow)
#   Using cached SQLAlchemy-1.4.52-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Collecting sqlalchemy-jsonfield>=1.0 (from apache-airflow)
#   Using cached SQLAlchemy_JSONField-1.0.2-py3-none-any.whl (10 kB)
# Collecting tabulate>=0.7.5 (from apache-airflow)
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting tenacity!=8.2.0,>=6.2.0 (from apache-airflow)
#   Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Collecting termcolor>=1.1.0 (from apache-airflow)
#   Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting unicodecsv>=0.14.1 (from apache-airflow)
#   Using cached unicodecsv-0.14.1-py3-none-any.whl
# Collecting universal-pathlib>=0.2.2 (from apache-airflow)
#   Using cached universal_pathlib-0.2.2-py3-none-any.whl (46 kB)
# Collecting werkzeug<3,>=2.0 (from apache-airflow)
#   Using cached werkzeug-2.3.8-py3-none-any.whl (242 kB)
# Collecting apache-airflow-providers-common-io (from apache-airflow)
#   Using cached apache_airflow_providers_common_io-1.3.1-py3-none-any.whl (16 kB)
# Collecting apache-airflow-providers-common-sql (from apache-airflow)
#   Using cached apache_airflow_providers_common_sql-1.13.0-py3-none-any.whl (46 kB)
# Collecting apache-airflow-providers-fab>=1.0.2 (from apache-airflow)
#   Using cached apache_airflow_providers_fab-1.1.0-py3-none-any.whl (78 kB)
# Collecting apache-airflow-providers-ftp (from apache-airflow)
#   Using cached apache_airflow_providers_ftp-3.9.0-py3-none-any.whl (19 kB)
# Collecting apache-airflow-providers-http (from apache-airflow)
#   Using cached apache_airflow_providers_http-4.11.0-py3-none-any.whl (27 kB)
# Collecting apache-airflow-providers-imap (from apache-airflow)
#   Using cached apache_airflow_providers_imap-3.6.0-py3-none-any.whl (17 kB)
# Collecting apache-airflow-providers-smtp (from apache-airflow)
#   Using cached apache_airflow_providers_smtp-1.7.0-py3-none-any.whl (22 kB)
# Collecting apache-airflow-providers-sqlite (from apache-airflow)
#   Using cached apache_airflow_providers_sqlite-3.8.0-py3-none-any.whl (13 kB)
# Collecting Mako (from alembic<2.0,>=1.13.1->apache-airflow)
#   Using cached Mako-1.3.3-py3-none-any.whl (78 kB)
# Collecting typing-extensions>=4 (from alembic<2.0,>=1.13.1->apache-airflow)
#   Using cached typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting flask-appbuilder==4.4.1 (from apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_AppBuilder-4.4.1-py3-none-any.whl (2.2 MB)
# Collecting flask-login>=0.6.2 (from apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Login-0.6.3-py3-none-any.whl (17 kB)
# Collecting apispec[yaml]<7,>=6.0.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached apispec-6.6.1-py3-none-any.whl (30 kB)
# Collecting colorama<1,>=0.3.9 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting click<9,>=8 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting email-validator>=1.0.5 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting Flask-Babel<3,>=1 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting Flask-Limiter<4,>3 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_Limiter-3.6.0-py3-none-any.whl (28 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Flask_JWT_Extended-4.6.0-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow<4,>=3.18.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached marshmallow-3.21.2-py3-none-any.whl (49 kB)
# Collecting marshmallow-sqlalchemy<0.29.0,>=0.22.0 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached marshmallow_sqlalchemy-0.28.2-py2.py3-none-any.whl (16 kB)
# Collecting prison<1.0.0,>=0.2.1 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached SQLAlchemy_Utils-0.41.2-py3-none-any.whl (93 kB)
# Collecting WTForms<4 (from flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached wtforms-3.1.2-py3-none-any.whl (145 kB)
# Collecting clickclick<21,>=1.2 (from connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Collecting PyYAML<7,>=5.1 (from connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Collecting inflection<0.6,>=0.3.1 (from connexion[flask]<3.0,>=2.10.0->apache-airflow)
#   Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting werkzeug<3,>=2.0 (from apache-airflow)
#   Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Collecting pytz>2021.1 (from croniter>=2.0.2->apache-airflow)
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting cffi>=1.12 (from cryptography>=39.0.0->apache-airflow)
#   Using cached cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.13->apache-airflow)
#   Using cached wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Collecting cachelib<0.10.0,>=0.9.0 (from flask-caching>=1.5.0->apache-airflow)
#   Using cached cachelib-0.9.0-py3-none-any.whl (15 kB)
# Collecting zipp>=0.5 (from importlib_metadata>=6.5->apache-airflow)
#   Using cached zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->apache-airflow)
#   Using cached rpds_py-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting uc-micro-py (from linkify-it-py>=2.0.0->apache-airflow)
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.1.0->apache-airflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting wirerope>=0.4.7 (from methodtools>=0.4.7->apache-airflow)
#   Using cached wirerope-0.4.7-py3-none-any.whl
# Collecting importlib_metadata>=6.5 (from apache-airflow)
#   Using cached importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Collecting tzdata>=2020.1 (from pendulum<4.0,>=2.1.2->apache-airflow)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting time-machine>=2.6.0 (from pendulum<4.0,>=2.1.2->apache-airflow)
#   Using cached time_machine-2.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Collecting docutils (from python-daemon>=3.0.0->apache-airflow)
#   Using cached docutils-0.21.2-py3-none-any.whl (587 kB)
# Collecting setuptools>=62.4.0 (from python-daemon>=3.0.0->apache-airflow)
#   Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Collecting six>=1.5 (from python-dateutil>=2.3->apache-airflow)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting text-unidecode>=1.3 (from python-slugify>=5.0->apache-airflow)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27.0->apache-airflow)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27.0->apache-airflow)
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27.0->apache-airflow)
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27.0->apache-airflow)
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy<2.0,>=1.4.36->apache-airflow)
#   Using cached greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
# Collecting more-itertools>=9.0.0 (from apache-airflow-providers-common-sql->apache-airflow)
#   Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Collecting sqlparse>=0.4.2 (from apache-airflow-providers-common-sql->apache-airflow)
#   Using cached sqlparse-0.5.0-py3-none-any.whl (43 kB)
# Collecting aiohttp>=3.9.2 (from apache-airflow-providers-http->apache-airflow)
#   Using cached aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting requests_toolbelt (from apache-airflow-providers-http->apache-airflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting anyio (from httpx->apache-airflow)
#   Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Collecting httpcore==1.* (from httpx->apache-airflow)
#   Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Collecting sniffio (from httpx->apache-airflow)
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->apache-airflow)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.24.0 (from opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.24.0 (from opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.24.0-py3-none-any.whl (16 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
# Collecting grpcio<2.0.0,>=1.0.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached grpcio-1.63.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
# Collecting opentelemetry-sdk~=1.24.0 (from opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
# Collecting protobuf<5.0,>=3.19 (from opentelemetry-proto==1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow)
#   Using cached frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow)
#   Using cached multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow)
#   Using cached yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.9.2->apache-airflow-providers-http->apache-airflow)
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=39.0.0->apache-airflow)
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx->apache-airflow)
#   Using cached exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=1.0.5->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Collecting Babel>=2.3 (from Flask-Babel<3,>=1->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached Babel-2.15.0-py3-none-any.whl (9.6 MB)
# Collecting limits>=2.8 (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached limits-3.12.0-py3-none-any.whl (45 kB)
# Collecting ordered-set<5,>4 (from Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-sdk~=1.24.0->opentelemetry-exporter-otlp-proto-grpc==1.24.0->opentelemetry-exporter-otlp->apache-airflow)
#   Using cached opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Collecting importlib-resources>=1.3 (from limits>=2.8->Flask-Limiter<4,>3->flask-appbuilder==4.4.1->apache-airflow-providers-fab>=1.0.2->apache-airflow)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: unicodecsv, text-unidecode, pytz, lockfile, cron-descriptor, colorlog, zipp, wrapt, urllib3, uc-micro-py, tzdata, typing-extensions, termcolor, tenacity, tabulate, sqlparse, sniffio, six, setuptools, setproctitle, rpds-py, PyYAML, python-slugify, pyjwt, pygments, pycparser, psutil, protobuf, pluggy, pathspec, packaging, ordered-set, opentelemetry-semantic-conventions, multidict, more-itertools, mdurl, markupsafe, lazy-object-proxy, itsdangerous, inflection, importlib-resources, idna, h11, grpcio, greenlet, google-re2, fsspec, frozenlist, exceptiongroup, docutils, dnspython, dill, configupdater, colorama, click, charset-normalizer, certifi, cachelib, blinker, Babel, attrs, async-timeout, argcomplete, yarl, WTForms, wirerope, werkzeug, universal-pathlib, sqlalchemy, rfc3339-validator, requests, referencing, python-dateutil, python-daemon, prison, opentelemetry-proto, marshmallow, markdown-it-py, Mako, linkify-it-py, jinja2, importlib_metadata, httpcore, gunicorn, googleapis-common-protos, email-validator, deprecated, clickclick, cffi, asgiref, apispec, anyio, aiosignal, time-machine, sqlalchemy-utils, sqlalchemy-jsonfield, rich, requests_toolbelt, python-nvd3, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, methodtools, mdit-py-plugins, marshmallow-sqlalchemy, marshmallow-oneofschema, limits, jsonschema-specifications, httpx, flask, cryptography, croniter, alembic, aiohttp, rich-argparse, pendulum, opentelemetry-sdk, jsonschema, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-Limiter, Flask-JWT-Extended, flask-caching, Flask-Babel, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, flask-appbuilder, connexion, opentelemetry-exporter-otlp, apache-airflow-providers-common-sql, apache-airflow-providers-sqlite, apache-airflow-providers-smtp, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, apache-airflow-providers-fab, apache-airflow-providers-common-io, apache-airflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torch 2.2.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-nccl-cu12==2.19.3; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.2.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# sphinx 5.0.2 requires docutils<0.19,>=0.14, but you have docutils 0.21.2 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.52 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.3.0 which is incompatible.
# tensorflow 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.3 which is incompatible.
# Successfully installed Babel-2.15.0 Flask-Babel-2.0.0 Flask-JWT-Extended-4.6.0 Flask-Limiter-3.6.0 Flask-SQLAlchemy-2.5.1 Mako-1.3.3 PyYAML-6.0.1 WTForms-3.1.2 aiohttp-3.9.5 aiosignal-1.3.1 alembic-1.13.1 anyio-3.7.1 apache-airflow-2.9.1 apache-airflow-providers-common-io-1.3.1 apache-airflow-providers-common-sql-1.13.0 apache-airflow-providers-fab-1.1.0 apache-airflow-providers-ftp-3.9.0 apache-airflow-providers-http-4.11.0 apache-airflow-providers-imap-3.6.0 apache-airflow-providers-smtp-1.7.0 apache-airflow-providers-sqlite-3.8.0 apispec-6.6.1 argcomplete-3.3.0 asgiref-3.8.1 async-timeout-4.0.3 attrs-23.2.0 blinker-1.8.2 cachelib-0.9.0 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 clickclick-20.10.2 colorama-0.4.6 colorlog-4.8.0 configupdater-3.2 connexion-2.14.2 cron-descriptor-1.4.3 croniter-2.0.5 cryptography-42.0.7 deprecated-1.2.14 dill-0.3.8 dnspython-2.6.1 docutils-0.18.1 email-validator-2.1.1 exceptiongroup-1.2.1 flask-2.2.5 flask-appbuilder-4.4.1 flask-caching-2.3.0 flask-login-0.6.3 flask-session-0.5.0 flask-wtf-1.2.1 frozenlist-1.4.1 fsspec-2023.6.0 google-re2-1.1.20240501 googleapis-common-protos-1.63.0 greenlet-3.0.3 grpcio-1.63.0 gunicorn-22.0.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 importlib-resources-6.4.0 importlib_metadata-7.0.0 inflection-0.5.1 itsdangerous-2.2.0 jinja2-3.1.4 jsonschema-4.19.2 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 limits-3.12.0 linkify-it-py-2.0.3 lockfile-0.12.2 markdown-it-py-3.0.0 markupsafe-2.1.5 marshmallow-3.21.2 marshmallow-oneofschema-3.1.1 marshmallow-sqlalchemy-0.28.2 mdit-py-plugins-0.4.0 mdurl-0.1.2 methodtools-0.4.7 more-itertools-10.1.0 multidict-6.0.5 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-exporter-otlp-proto-http-1.24.0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 ordered-set-4.1.0 packaging-24.0 pathspec-0.12.1 pendulum-3.0.0 pluggy-1.5.0 prison-0.2.1 protobuf-3.20.3 psutil-5.9.5 pycparser-2.22 pygments-2.16.1 pyjwt-2.8.0 python-daemon-3.0.1 python-dateutil-2.8.2 python-nvd3-0.16.0 python-slugify-8.0.4 pytz-2023.4 referencing-0.35.1 requests-2.31.0 requests_toolbelt-1.0.0 rfc3339-validator-0.1.4 rich-13.7.1 rich-argparse-1.4.0 rpds-py-0.18.1 setproctitle-1.3.3 setuptools-67.7.2 six-1.16.0 sniffio-1.3.1 sqlalchemy-1.4.52 sqlalchemy-jsonfield-1.0.2 sqlalchemy-utils-0.41.2 sqlparse-0.5.0 tabulate-0.9.0 tenacity-8.3.0 termcolor-2.4.0 text-unidecode-1.3 time-machine-2.14.1 typing-extensions-4.11.0 tzdata-2024.1 uc-micro-py-1.0.3 unicodecsv-0.14.1 universal-pathlib-0.2.2 urllib3-2.0.7 werkzeug-2.2.3 wirerope-0.4.7 wrapt-1.14.1 yarl-1.9.4 zipp-3.18.1

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime

default_args = {
    'owner': 'airflow',
    'start_date': datetime(2024, 5, 25),
    'retries': 1,
}

with DAG(
    'ETL_process',
    default_args=default_args,
    description='DAG for ETL Process',
    schedule=None,
) as dag:
    extraction = PythonOperator(
        task_id='extraction',
        python_callable=extract
    )

    transform = PythonOperator(
        task_id='transformation',
        python_callable=transform
    )
    load = PythonOperator(
        task_id='load',
        python_callable=load
    )

    extraction >> transform >> load
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-89-908d77afb3f5> in <cell line: 1>()
# ----> 1 from airflow import DAG
#       2 from airflow.operators.python import PythonOperator
#       3 from datetime import datetime
#       4
#       5 default_args = {
#
# /usr/local/lib/python3.10/dist-packages/airflow/__init__.py in __getattr__(name)
#     107     import importlib
#     108
# --> 109     mod = importlib.import_module(module_path, __name__)
#     110     if attr_name:
#     111         val = getattr(mod, attr_name)
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.10/dist-packages/airflow/models/dag.py in <module>
#      97 from airflow.models.abstractoperator import AbstractOperator, TaskStateChangeCallback
#      98 from airflow.models.base import Base, StringID
# ---> 99 from airflow.models.baseoperator import BaseOperator
#     100 from airflow.models.dagcode import DagCode
#     101 from airflow.models.dagpickle import DagPickle
#
# /usr/local/lib/python3.10/dist-packages/airflow/models/baseoperator.py in <module>
#      81 from airflow.models.param import ParamsDict
#      82 from airflow.models.pool import Pool
# ---> 83 from airflow.models.taskinstance import TaskInstance, clear_task_instances
#      84 from airflow.models.taskmixin import DependencyMixin
#      85 from airflow.serialization.enums import DagAttributeTypes
#
# /usr/local/lib/python3.10/dist-packages/airflow/models/taskinstance.py in <module>
#      96 from airflow.models.taskmap import TaskMap
#      97 from airflow.models.taskreschedule import TaskReschedule
# ---> 98 from airflow.models.xcom import LazyXComAccess, XCom
#      99 from airflow.plugins_manager import integrate_macros_plugins
#     100 from airflow.sentry import Sentry
#
# /usr/local/lib/python3.10/dist-packages/airflow/models/xcom.py in <module>
#      53 from airflow.utils import timezone
#      54 from airflow.utils.helpers import exactly_one, is_container
# ---> 55 from airflow.utils.json import XComDecoder, XComEncoder
#      56 from airflow.utils.log.logging_mixin import LoggingMixin
#      57 from airflow.utils.session import NEW_SESSION, provide_session
#
# /usr/local/lib/python3.10/dist-packages/airflow/utils/json.py in <module>
#      23 from typing import Any
#      24
# ---> 25 from flask.json.provider import JSONProvider
#      26
#      27 from airflow.serialization.serde import CLASSNAME, DATA, SCHEMA_ID, deserialize, serialize
#
# /usr/local/lib/python3.10/dist-packages/flask/__init__.py in <module>
#       2 from markupsafe import Markup
#       3
# ----> 4 from . import json as json
#       5 from .app import Flask as Flask
#       6 from .app import Request as Request
#
# /usr/local/lib/python3.10/dist-packages/flask/json/__init__.py in <module>
#       6 from jinja2.utils import htmlsafe_json_dumps as _jinja_htmlsafe_dumps
#       7
# ----> 8 from ..globals import current_app
#       9 from .provider import _default
#      10
#
# /usr/local/lib/python3.10/dist-packages/flask/globals.py in <module>
#       2 from contextvars import ContextVar
#       3
# ----> 4 from werkzeug.local import LocalProxy
#       5
#       6 if t.TYPE_CHECKING:  # pragma: no cover
#
# /usr/local/lib/python3.10/dist-packages/werkzeug/__init__.py in <module>
#       1 from .serving import run_simple as run_simple
# ----> 2 from .test import Client as Client
#       3 from .wrappers import Request as Request
#       4 from .wrappers import Response as Response
#       5
#
# /usr/local/lib/python3.10/dist-packages/werkzeug/test.py in <module>
#      17 from ._internal import _wsgi_decoding_dance
#      18 from ._internal import _wsgi_encoding_dance
# ---> 19 from .datastructures import Authorization
#      20 from .datastructures import CallbackDict
#      21 from .datastructures import CombinedMultiDict
#
# /usr/local/lib/python3.10/dist-packages/werkzeug/datastructures/__init__.py in <module>
#       9 from .csp import ContentSecurityPolicy as ContentSecurityPolicy
#      10 from .etag import ETags as ETags
# ---> 11 from .file_storage import FileMultiDict as FileMultiDict
#      12 from .file_storage import FileStorage as FileStorage
#      13 from .headers import EnvironHeaders as EnvironHeaders
#
# /usr/local/lib/python3.10/dist-packages/werkzeug/datastructures/file_storage.py in <module>
#       6 from os import fspath
#       7
# ----> 8 from .._internal import _plain_int
#       9 from .structures import MultiDict
#      10
#
# ImportError: cannot import name '_plain_int' from 'werkzeug._internal' (/usr/local/lib/python3.10/dist-packages/werkzeug/_internal.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
